# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
custs = pd.read_csv('./customers.tsv', sep='\t')
custs.head()
# Out:
#    ID  age gender income_class relationship_status  years_as_customer
# 0   0   26      F          Low             Married                3.4
# 1   1   18    Unk       Medium             Married                4.2
# 2   2   49      F       Medium              Single                2.4
# 3   3   40      F          Low              Single                4.7
# 4   4   27      F       Medium              Single                4.7

# %%
plt.rc('font', **{'size'   : 14})
fig, axs = plt.subplots(1,3,figsize=(20,10))
for field, idx in zip(['gender', 'income_class', 'relationship_status'], range(3)):
    custs[field].value_counts().plot.bar(ax=axs[idx])
# Out:
# C:\dev\tools\winpython34\python-3.4.4.amd64\lib\site-packages\matplotlib\font_manager.py:1288: UserWarning: findfont: Font family ['normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
custs.plot.scatter(x='age', y='years_as_customer')
# Out:
# C:\dev\tools\winpython34\python-3.4.4.amd64\lib\site-packages\matplotlib\font_manager.py:1288: UserWarning: findfont: Font family ['normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
